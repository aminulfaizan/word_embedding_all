# %%
import pandas as pd
import multiprocessing
import numpy as np
import json
import string
import re
import time
from pprint import pprint
import fasttext

# %%
cd facebook_fastttext
# Out:
# C:\Users\Inquisitive\Desktop\models\fasttext\facebook_fastttext

# %%
pwd
# Out:
# 'C:\\Users\\Inquisitive\\Desktop\\models\\fasttext\\facebook_fastttext'

# %% [markdown]
# ## semantic_analogy_fb_fast_skipgram_m5m10d100d300w5

# %%
skip_model_fasttext100_m5_w5=fasttext.load_model('fasttext_model100.bin')
skip_model_fasttext300_m5_w5=fasttext.load_model('fasttext_model300.bin')
skip_model_fasttext100_m10_w5=fasttext.load_model('fasttext_model100min10.bin')
skip_model_fasttext300_m10_w5=fasttext.load_model('fasttext_modeld300_min10.bin')

# %%
pwd
# Out:
# 'C:\\Users\\Inquisitive\\Desktop\\models\\fasttext\\facebook_fastttext'

# %%
# Load your own trained FastText model
# Replace 'path_to_your_model' with the path to your trained model file
# For example: 'fasttext_model.bin' or 'fasttext_model.vec'
#model_path = 'path_to_your_model'
#model = FastText.load_fasttext_format(model_path)

##skip_model_fasttext100_m5_w5.get_analogies("ছাত্রলীগ","আওয়ামীলীগ", "বিএনপি", k=3)
# Syntactic and Semantic Analogy Task
def analogy_task_from_file_fbfastext_skip(file_path):
    results1 = []
    results2 = []
    results3 = []
    results4 = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            words = line.strip().split()
            if len(words) == 3:
                positive, negative, target = words
                
                result1 = skip_model_fasttext100_m5_w5.get_analogies(positive, negative, target, k=3)               
                results1.append((f"{positive} - {negative} + {target}", result1))
                print('................প্রথম......................')
                print(f"{positive} - {negative} + {target} = {result1}") 
                
                result2 = skip_model_fasttext300_m5_w5.get_analogies(positive, negative, target, k=3)
                results2.append((f"{positive} - {negative} + {target}", result2))
                print('.................দ্বিতীয়.....................')
                print(f"{positive} - {negative} + {target} = {result2}")
                
                result3 = skip_model_fasttext100_m10_w5.get_analogies(positive, negative, target, k=3)
                results3.append((f"{positive} - {negative} + {target}", result3))
                print('..................ৃতীয়....................')
                print(f"{positive} - {negative} + {target} = {result3}")
                
                result4 = skip_model_fasttext300_m10_w5.get_analogies(positive, negative, target, k=3)
                results4.append((f"{positive} - {negative} + {target}", result4))
                print('...................চতুর্থ...................')
                print(f"{positive} - {negative} + {target} = {result4}")
            else:
                continue

    df1 = pd.DataFrame(results1, columns=['Input1', 'Output1'])
    df2 = pd.DataFrame(results2, columns=['Input2', 'Output2'])
    df3 = pd.DataFrame(results3, columns=['Input3', 'Output3'])
    df4 = pd.DataFrame(results4, columns=['Input4', 'Output4'])
    return df1,df2,df3,df4

# File path for analogy tasks and most similar word queries
file_path = 'test_bangal_semantic_analogy_final.txt'

# Perform analogy tasks and most similar word queries from the file
semantic_analogy_skip_model_fasttext100_m5_w5 = analogy_task_from_file_fbfastext_skip(file_path)
semantic_analogy_skip_model_fasttext300_m5_w5 = analogy_task_from_file_fbfastext_skip(file_path)
semantic_analogy_skip_model_fasttext100_m10_w5 = analogy_task_from_file_fbfastext_skip(file_path)
semantic_analogy_skip_model_fasttext300_m10_w5 = analogy_task_from_file_fbfastext_skip(file_path)
# Out:
# ................প্রথম......................
# বেইজিং - চিন + রাশিয়া = [(0.8256369829177856, 'রাশিয়ার'), (0.8214641213417053, 'মস্কোর'), (0.8134115934371948, 'রাশিয়াকে')]
# .................দ্বিতীয়.....................
# বেইজিং - চিন + রাশিয়া = [(0.7016711831092834, 'রাশিয়াও'), (0.6939601302146912, 'রাশিয়ার'), (0.6883706450462341, 'রাশিয়াযুক্তরাষ্ট্র')]
# ..................ৃতীয়....................
# বেইজিং - চিন + রাশিয়া = [(0.8045061826705933, 'রাশিয়ার'), (0.8041933178901672, 'রাশিয়াকে'), (0.7760380506515503, 'ইউক্রেনও')]
# ...................চতুর্থ...................
# বেইজিং - চিন + রাশিয়া = [(0.7064536213874817, 'রাশিয়ার'), (0.6851921677589417, 'রাশিয়াযুক্তরাষ্ট্র'), (0.6815395951271057, 'রাশিয়াসৌদি')]
# ................প্রথম......................
# মস্কো - রাশিয়া + ইউক্রেন = [(0.8789963126182556, 'কিয়েভ'), (0.8720390200614929, 'ইউক্রেনের'), (0.8683600425720215, 'ইউক্রেনও')]
# .................দ্বিতীয়.....................
# ...

# %%
# Load your own trained FastText model
# Replace 'path_to_your_model' with the path to your trained model file
# For example: 'fasttext_model.bin' or 'fasttext_model.vec'
#model_path = 'path_to_your_model'
#model = FastText.load_fasttext_format(model_path)

##skip_model_fasttext100_m5_w5.get_analogies("ছাত্রলীগ","আওয়ামীলীগ", "বিএনপি", k=3)
# Syntactic and Semantic Analogy Task
def analogy_task_from_file_fbfastext_skip(file_path):
    results1 = []
    results2 = []
    results3 = []
    results4 = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            words = line.strip().split()
            if len(words) == 3:
                positive, negative, target = words
                
                result1 = skip_model_fasttext100_m5_w5.get_analogies(positive, negative, target, k=3)               
                results1.append((f"{positive} - {negative} + {target}", result1))
                
                #print(f"('{positive}','{negative}','{target}'):{result1}") 
                
                
                result2 = skip_model_fasttext300_m5_w5.get_analogies(positive, negative, target, k=3)
                results2.append((f"{positive} - {negative} + {target}", result2))
                
                #print(f" ('{positive}','{negative}','{target}'): {result2}")
                
                result3 = skip_model_fasttext100_m10_w5.get_analogies(positive, negative, target, k=3)
                results3.append((f"{positive} - {negative} + {target}", result3))
                
                #print(f"('{positive}','{negative}','{target}'): = {result3}")
                
                result4 = skip_model_fasttext300_m10_w5.get_analogies(positive, negative, target, k=3)
                results4.append((f"{positive} - {negative} + {target}", result4))
                
                print(f"('{positive}','{negative}','{target}'): {result4}")

    df1 = pd.DataFrame(results1, columns=['Input1', 'Output1'])
    df2 = pd.DataFrame(results2, columns=['Input2', 'Output2'])
    df3 = pd.DataFrame(results3, columns=['Input3', 'Output3'])
    df4 = pd.DataFrame(results4, columns=['Input4', 'Output4'])
    return df1,df2,df3,df4

# File path for analogy tasks and most similar word queries
file_path = 'analogy-semantic-game-country-player.txt'

# Perform analogy tasks and most similar word queries from the file
semantic_analogy_skip_model_fasttext100_m5_w5 = analogy_task_from_file_fbfastext_skip(file_path)
semantic_analogy_skip_model_fasttext300_m5_w5 = analogy_task_from_file_fbfastext_skip(file_path)
semantic_analogy_skip_model_fasttext100_m10_w5 = analogy_task_from_file_fbfastext_skip(file_path)
semantic_analogy_skip_model_fasttext300_m10_w5 = analogy_task_from_file_fbfastext_skip(file_path)
# Out:
# ('এমবাপে','ফ্রান্স','ব্রাজিল'): [(0.8021990060806274, 'নেইমার'), (0.7901788949966431, 'নেইমারে'), (0.7796345949172974, 'নেইমারও')]
# ('এমবাপে','ফ্রান্স','পর্তুগাল'): [(0.7558646202087402, 'এমবাপেরা'), (0.7512322664260864, 'এমবাপেই'), (0.7478843927383423, 'রোনালদোয়')]
# ('রোনালদো','পর্তুগাল','আর্জেন্টিনা'): [(0.8288825154304504, 'মেসি'), (0.7945346832275391, 'লিওনেল'), (0.794029712677002, 'মেসির')]
# ('নেইমার','ব্রাজিল','ফ্রান্স'): [(0.7212903499603271, 'এমবাপে'), (0.7011503577232361, 'এমবাপেও'), (0.6954763531684875, 'এমবাপের')]
# ('নেইমার','ব্রাজিল','পর্তুগাল'): [(0.7066062092781067, 'পর্তুগালও'), (0.7042072415351868, 'পর্তুগালই'), (0.7018634080886841, 'রোনালদোনেইমার')]
# ('নেইমার','ব্রাজিল','আর্জেন্টিনা'): [(0.8716630935668945, 'মেসি'), (0.8395233750343323, 'নেইমারই'), (0.837475061416626, 'লিওনেল')]
# ('মেসি','আর্জেন্টিনা','পর্তুগাল'): [(0.7642070651054382, 'পর্তুগালই'), (0.762535572052002, 'পর্তুগালও'), (0.7362213730812073, 'পর্তুগালের')]
# ...

# %% [markdown]
# # semantic_analogy_fb_fast_m5m10d_cbow_100d300w5

# %%
cbow_fasttext_model100_min5_w5=fasttext.load_model('cbow_fasttext_model100_min5_w5.bin')
cbow_fasttext_model300_min5_w5=fasttext.load_model('cbow_fasttext_model300_min5_w5.bin')
cbow_fasttext_model100min10_w5=fasttext.load_model('cbow_fasttext_model100min10.bin')
cbow_fasttext_model300_min10_w5=fasttext.load_model('cbow_fasttext_model300_min10.bin')
# Load your own trained FastText model
# Replace 'path_to_your_model' with the path to your trained model file
# For example: 'fasttext_model.bin' or 'fasttext_model.vec'
#model_path = 'path_to_your_model'
#model = FastText.load_fasttext_format(model_path)

# %%
##skip_model_fasttext100_m5_w5.get_analogies("ছাত্রলীগ","আওয়ামীলীগ", "বিএনপি", k=3)
# Syntactic and Semantic Analogy Task
def analogy_task_from_file_fbfastext_cbow(file_path):
    results1 = []
    results2 = []
    results3 = []
    results4 = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            words = line.strip().split()
            if len(words) == 3:
                positive, negative, target = words
                
                result1 = cbow_fasttext_model100_min5_w5.get_analogies(positive, negative, target, k=3)               
                results1.append((f"{positive} - {negative} + {target}", result1))
                print('................প্রথম......................')
                print(f"{positive} - {negative} + {target} = {result1}") 
                
                result2 = cbow_fasttext_model300_min5_w5.get_analogies(positive, negative, target, k=3)
                results2.append((f"{positive} - {negative} + {target}", result2))
                print('.................দ্বিতীয়.....................')
                print(f"{positive} - {negative} + {target} = {result2}")
                
                result3 = cbow_fasttext_model100min10_w5.get_analogies(positive, negative, target, k=3)
                results3.append((f"{positive} - {negative} + {target}", result3))
                print('..................ৃতীয়....................')
                print(f"{positive} - {negative} + {target} = {result3}")
                
                result4 = cbow_fasttext_model300_min10_w5.get_analogies(positive, negative, target, k=3)
                results4.append((f"{positive} - {negative} + {target}", result4))
                print('...................চতুর্থ...................')
                print(f"{positive} - {negative} + {target} = {result4}")

    df1 = pd.DataFrame(results1, columns=['Input1', 'Output1'])
    df2 = pd.DataFrame(results2, columns=['Input2', 'Output2'])
    df3 = pd.DataFrame(results3, columns=['Input3', 'Output3'])
    df4 = pd.DataFrame(results4, columns=['Input4', 'Output4'])
    return df1,df2,df3,df4

# File path for analogy tasks and most similar word queries
file_path = 'test_bangal_semantic_analogy_final.txt'

# Perform analogy tasks and most similar word queries from the file
semantic_cbow_fasttext_model100_min5_w5 = analogy_task_from_file_fbfastext_cbow(file_path)
semantic_cbow_fasttext_model300_min5_w5 = analogy_task_from_file_fbfastext_cbow(file_path)
semantic_cbow_fasttext_model100_min10_w5 = analogy_task_from_file_fbfastext_cbow(file_path)
semantic_cbow_fasttext_model300_min10_w5 = analogy_task_from_file_fbfastext_cbow(file_path)

# %%
data_frame = semantic_cbow_fasttext_model100_min5_w5[0]
data_frame.to_excel('semantic_cbow_fasttext_model100_min5_w5_cbow1.xlsx', index=False, encoding='utf-8')

# %%
data_frame = semantic_cbow_fasttext_model300_min5_w5[1]
data_frame.to_excel('semantic_cbow_fasttext_model300_min5_w5_cbow2.xlsx', index=False, encoding='utf-8')

# %%
data_frame = semantic_cbow_fasttext_model100_min10_w5[2]
data_frame.to_excel('semantic_cbow_fasttext_model100_min10_w5_cbow3.xlsx', index=False, encoding='utf-8')

# %%
data_frame = semantic_cbow_fasttext_model300_min10_w5[3]
data_frame.to_excel('semantic_cbow_fasttext_model300_min10_w5_cbow4.xlsx', index=False, encoding='utf-8')

# %%
cd facebook_fastttext
# Out:
# C:\Users\Inquisitive\Desktop\models\fasttext\facebook_fastttext

# %% [markdown]
# ## fasttext facbook min25 epoch20

# %%
import pandas as pd
import multiprocessing
import numpy as np
import json
import string
import re
from pprint import pprint
import pickle
import fasttext

# %%
model = fasttext.load_model('testfasttext_model100_epoch50_min25.bin')

# %%
# Load your own trained FastText model
# Replace 'path_to_your_model' with the path to your trained model file
# For example: 'fasttext_model.bin' or 'fasttext_model.vec'
#model_path = 'path_to_your_model'
#model = FastText.load_fasttext_format(model_path)
# Load the pre-trained FastText model
prediction={}
model = fasttext.load_model('testfasttext_model100_epoch50_min25.bin')
##skip_model_fasttext100_m5_w5.get_analogies("ছাত্রলীগ","আওয়ামীলীগ", "বিএনপি", k=3)
# Syntactic and Semantic Analogy Task
def analogy(file_path):
    results1 = []

    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            words = line.strip().split()
            if len(words) == 3:
                positive, negative, target = words
                
                result1 = model.get_analogies(positive, negative, target, k=3)               
                results1.append((f"{positive} - {negative} + {target}", result1))
                
                print(f" ('{positive}', '{negative}', '{target}'): {result1},") 
                prediction = (f" ('{positive}', '{negative}', '{target}'): {result1} ")


    df1 = pd.DataFrame(results1, columns=['Input1', 'Output1'],)

    return df1

# File path for analogy tasks and most similar word queries
file_path = 'test_bangal_semantic_analogy_final.txt'

# Perform analogy tasks and most similar word queries from the file
semantic_skip_fasttext_model100_min25_epoch20 = analogy(file_path)
# Out:
# ...
#  ('বেইজিং', 'চিন', 'রাশিয়া'): [(0.8195729851722717, 'রাশিয়ার'), (0.8118793368339539, 'রাশিয়াকে'), (0.809002161026001, 'মস্কো')],
#  ('মস্কো', 'রাশিয়া', 'ইউক্রেন'): [(0.8893406987190247, 'কিয়েভ'), (0.8821157217025757, 'ইউক্রেনের'), (0.8574286699295044, 'ইউক্রেনও')],
#  ('বেইজিং', 'চিন', 'ইরান'): [(0.8365445733070374, 'তেহরান'), (0.7933176159858704, 'ইরানকে'), (0.7919766306877136, 'তেহরানের')],
#  ('মস্কো', 'রাশিয়া', 'আফগানিস্তান'): [(0.8317973613739014, 'আফগানিস্তানের'), (0.8196224570274353, 'আফগানিস্তানও'), (0.8169159293174744, 'আফগানিস্তানেরও')],
#  ('মস্কো', 'রাশিয়া', 'ভারত'): [(0.8323218822479248, 'ভারতের'), (0.7916460633277893, 'নয়াদিল্লি'), (0.7811681032180786, 'নয়াদিল্লিকে')],
#  ('ইউক্রেন', 'কিয়েভ', 'মস্কো'): [(0.8928510546684265, 'রাশিয়া'), (0.8745988011360168, 'রাশিয়া'), (0.8694638013839722, 'রাশিয়ার')],
#  ('ইউক্রেন', 'কিয়েভ', 'দিল্লি'): [(0.7908420562744141, 'দিল্লিতে'), (0.7893385887145996, 'গুজরাট'), (0.7870804667472839, 'দিল্লির')],
# ...

# %% [markdown]
# # ম্যাট্রিক্স

# %% [markdown]
# # this one is working .......3333333333333333333

# %%
# Initialize an empty dictionary to store key-value pairs
analogy_dict = {}

# File paths for the key and value files
file_path1 = 'test_last.txt'
file_path2 = 'test_truth.txt'
result=[]

# Read the key and value files and populate the dictionary
with open(file_path1, 'r', encoding='utf-8') as file1, open(file_path2, 'r', encoding='utf-8') as file2:
    keys = file1.readlines()
    values = file2.readlines()

    # Remove newline characters from the end of each line and split into lists of words
    keys = [tuple(line.strip().split()) for line in keys]
    values = [line.strip().split() for line in values]

    # Ensure the number of keys and values match
    if len(keys) == len(values):
        analogy_dict = dict(zip(keys, values))
    else:
        print("Error: The number of keys and values does not match.")

# Print the dictionary
for key, value in analogy_dict.items():
    print(f"{key}: {value}")
   # result.append((f"{key}: {value}"))
# Out:
# ('\ufeffবেইজিং', 'চিন', 'রাশিয়া'): ['মস্কো', 'মস্কোর', 'মস্কোও']
# ('মস্কো', 'রাশিয়া', 'ইউক্রেন'): ['কিয়েভ', 'কিয়েভের', 'কিয়েভও']
# ('বেইজিং', 'চিন', 'ইরান'): ['তেহরান', 'তেহরানের', 'তেহরানও']
# ('মস্কো', 'রাশিয়া', 'আফগানিস্তান'): ['কাবুল', 'কাবুলের', 'কাবুলও']
# ('মস্কো', 'রাশিয়া', 'ভারত'): ['দিল্লি', 'নয়াদিল্লি', 'দিল্লী']
# ('ইউক্রেন', 'কিয়েভ', 'মস্কো'): ['রাশিয়া', 'রাশিয়ার', 'রাশিয়াইউক্রেন']
# ('ইউক্রেন', 'কিয়েভ', 'দিল্লি'): ['ভারত', 'ভারতও', 'ভারতের']
# ('ইউক্রেন', 'কিয়েভ', 'বেইজিং'): ['চীন', 'চীনের', 'চিন']
# ('ইউক্রেন', 'কিয়েভ', 'তেহরান'): ['ইরান', 'ইরানের', 'ইরানযুক্তরাষ্ট্র']
# ('আমেরিকা', 'নিউইয়র্ক', 'মস্কো'): ['রাশিয়া', 'রাশিয়ার', 'রাশিয়াইউক্রেন']
# ('আমেরিকা', 'নিউইয়র্ক', 'তেহরান'): ['ইরান', 'ইরানের', 'ইরানযুক্তরাষ্ট্র']
# ('আমেরিকা', 'নিউইয়র্ক', 'কাবুল'): ['আফগান', 'তালেবান', 'আফগানিস্তান']
# ('আমেরিকা', 'নিউইয়র্ক', 'পিয়ংইয়ং'): ['কোরিয়া', 'কোরিয়ার', 'কোরিয়াও']
# ('আমেরিকা', 'নিউইয়র্ক', 'বেইজিং'): ['চীন', 'চীনের', 'চিন']
# ...

# %%
model.get_analogies("বেইজিং" , "চিন",  "রাশিয়া", k=3)
# Out:
# [(0.8195729851722717, 'রাশিয়ার'),
#  (0.8118793368339539, 'রাশিয়াকে'),
#  (0.809002161026001, 'মস্কো')]

# %%
# Initialize a counter for matching elements
matching_count = 0
not_matching_count = 0
count = 0
# Iterate through each group of tuples
for group_key, group_tuples in prediction.items():
    max_tuple = max(group_tuples, key=lambda x: x[0])
    string_part_of_max = max_tuple[1]

    if group_key in ground_truth:
        count+=1
        a = ground_truth[group_key]
        if string_part_of_max in a:
            matching_count += 1
        else:
            not_matching_count += 1
            print(string_part_of_max , count)
            print(group_key , count)
            
print(len(ground_truth))
print(len(prediction))
print(f"Number of matching elements: {matching_count}")
print(f"Number of no matching elements: {not_matching_count}")
# Out:
# রাশিয়ার 1
# ('বেইজিং', 'চিন', 'রাশিয়া') 1
# আফগানিস্তানের 4
# ('মস্কো', 'রাশিয়া', 'আফগানিস্তান') 4
# ভারতের 5
# ('মস্কো', 'রাশিয়া', 'ভারত') 5
# দিল্লিতে 7
# ('ইউক্রেন', 'কিয়েভ', 'দিল্লি') 7
# কোরিয়াকে 13
# ('আমেরিকা', 'নিউইয়র্ক', 'পিয়ংইয়ং') 13
# আফগানিস্তানে 19
# ('বাংলাদেশ', 'ঢাকা', 'কাবুল') 19
# তেলআবিবে 21
# ('বাংলাদেশ', 'ঢাকা', 'তেলআবিব') 21
# তেলআবিবে 25
# ('পাকিস্তান', 'ইসলামাবাদ', 'তেলআবিব') 25
# কুমিল্লা 27
# ('রাশিয়া', 'মস্কো', 'ঢাকা') 27
# জেদ্দায় 31
# ('রাশিয়া', 'মস্কো', 'জেদ্দা') 31
# ইসলামাবাদের 32
# ('রাশিয়া', 'মস্কো', 'ইসলামাবাদ') 32
# রানি 33
# ('রাজা', 'ছেলে', 'মেয়ে') 33
# রাজার 37
# ('রাজা', 'পুরুষ', 'নারী') 37
# রানির 38
# ('রানি', 'নারী', 'পুরুষ') 38
# নির্যাতন 39
# ('নারী', 'রানি', 'রাজা') 39
# পুরুষের 40
# ('পুরুষ', 'রাজা', 'রানি') 40
# ঐশ্বরিয়া 41
# ('রাজকুমার', 'ছেলে', 'মেয়ে') 41
# গ্রামের 43
# ('ছেলে', 'রাজকুমার', 'রাজকুমারী') 43
# মধ্যপাড়ার 44
# ('মেয়ে', 'রাজকুমারী', 'ছেলে') 44
# বিএনপির 45
# ('আওয়ামীলীগ', 'হাসিনা', 'খালেদা') 45
# জিয়াকে 46
# ...

# %% [markdown]
# ### semantic fbfastext results

# %%
# !pip install openpyxl
#for using xl sheet

# %%
# Save to Excel format
#excel_file_path = 'analogy_results.xlsx'
# Assuming the DataFrame is the first element of the tuple
data_frame = semantic_analogy_skip_model_fasttext100_m5_w5[0]
data_frame.to_excel('semantic_analogy_skip_model_fasttext100_m5_w5_skip1.xlsx', index=False, encoding='utf-8')
# Out:
# C:\Users\Inquisitive\anaconda3\envs\data_pre\lib\site-packages\pandas\util\_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)

# %%
data_frame = semantic_analogy_skip_model_fasttext300_m5_w5[1]
data_frame.to_excel('semantic_analogy_skip_model_fasttext300_m5_w5_skip2.xlsx', index=False, encoding='utf-8')

# %%
data_frame = semantic_analogy_skip_model_fasttext100_m10_w5[2]
data_frame.to_excel('semantic_analogy_skip_model_fasttext100_m10_w5_skip3.xlsx', index=False, encoding='utf-8')

# %%
data_frame = semantic_analogy_skip_model_fasttext300_m10_w5[3]
data_frame.to_excel('semantic_analogy_skip_model_fasttext300_m10_w5_skip4.xlsx', index=False, encoding='utf-8')

# %%
data_frame = semantic_analogy_skip_model_fasttext300_m10_w5[3]
data_frame.to_txt('semantic_analogy_skip_model_fasttext300_m10_w5_skip4.txt', index=False, encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 2
#       1 data_frame = semantic_analogy_skip_model_fasttext300_m10_w5[3]
# ----> 2 data_frame.to_txt('semantic_analogy_skip_model_fasttext300_m10_w5_skip4.txt', index=False, encoding='utf-8')
#
# File ~\anaconda3\envs\data_pre\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_txt'

# %%
type(semantic_analogy_skip_model_fasttext300_m5_w5)
# Out:
# tuple

# %% [markdown]
# ## semantic_analogy_fb_fast_m5m10d_cbow_100d300w5

# %%
# Load your own trained FastText model
# Replace 'path_to_your_model' with the path to your trained model file
# For example: 'fasttext_model.bin' or 'fasttext_model.vec'
#model_path = 'path_to_your_model'
#model = FastText.load_fasttext_format(model_path)

##skip_model_fasttext100_m5_w5.get_analogies("ছাত্রলীগ","আওয়ামীলীগ", "বিএনপি", k=3)
# Syntactic and Semantic Analogy Task
def analogy_task_from_file_fbfastext_cbow(file_path):
    results1 = []
    results2 = []
    results3 = []
    results4 = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            words = line.strip().split()
            if len(words) == 3:
                positive, negative, target = words
                
                result1 = cbow_fasttext_model100_min5_w5.get_analogies(positive, negative, target, k=3)               
                results1.append((f"{positive} - {negative} + {target}", result1))
                print('................প্রথম......................')
                print(f"{positive} - {negative} + {target} = {result1}") 
                
                result2 = cbow_fasttext_model300_min5_w5.get_analogies(positive, negative, target, k=3)
                results2.append((f"{positive} - {negative} + {target}", result2))
                print('.................দ্বিতীয়.....................')
                print(f"{positive} - {negative} + {target} = {result2}")
                
                result3 = cbow_fasttext_model100min10_w5.get_analogies(positive, negative, target, k=3)
                results3.append((f"{positive} - {negative} + {target}", result3))
                print('..................ৃতীয়....................')
                print(f"{positive} - {negative} + {target} = {result3}")
                
                result4 = cbow_fasttext_model300_min10_w5.get_analogies(positive, negative, target, k=3)
                results4.append((f"{positive} - {negative} + {target}", result4))
                print('...................চতুর্থ...................')
                print(f"{positive} - {negative} + {target} = {result4}")

    df1 = pd.DataFrame(results1, columns=['Input1', 'Output1'])
    df2 = pd.DataFrame(results2, columns=['Input2', 'Output2'])
    df3 = pd.DataFrame(results3, columns=['Input3', 'Output3'])
    df4 = pd.DataFrame(results4, columns=['Input4', 'Output4'])
    return df1,df2,df3,df4

# File path for analogy tasks and most similar word queries
file_path = 'test_bangal_semantic_analogy_final.txt'

# Perform analogy tasks and most similar word queries from the file
semantic_cbow_fasttext_model100_min5_w5 = analogy_task_from_file_fbfastext_cbow(file_path)
semantic_cbow_fasttext_model300_min5_w5 = analogy_task_from_file_fbfastext_cbow(file_path)
semantic_cbow_fasttext_model100_min10_w5 = analogy_task_from_file_fbfastext_cbow(file_path)
semantic_cbow_fasttext_model300_min10_w5 = analogy_task_from_file_fbfastext_cbow(file_path)


# Save to Excel format
#excel_file_path = 'analogy_results.xlsx'
# Assuming the DataFrame is the first element of the tuple
# Out:
# ................প্রথম......................
# বাংলাদেশ - ঢাকা + ইসলামাবাদ = [(0.7607256770133972, 'ইসলামাবাদভিত্তিক'), (0.7600564956665039, 'পাকিস্তানবাংলাদেশ'), (0.7597784996032715, 'সৌদিপাকিস্তান')]
# .................দ্বিতীয়.....................
# বাংলাদেশ - ঢাকা + ইসলামাবাদ = [(0.7225670218467712, 'ইসলামাবাদভিত্তিক'), (0.7051916122436523, 'পাকিস্তানবাংলাদেশ'), (0.6984373331069946, 'ইসলামাবাদের')]
# ..................ৃতীয়....................
# বাংলাদেশ - ঢাকা + ইসলামাবাদ = [(0.7521181106567383, 'পাকিস্তানযুক্তরাষ্ট্র'), (0.7498223185539246, 'পাকিস্তানবাংলাদেশ'), (0.7420822381973267, 'পাকিস্তানভিত্তিক')]
# ...................চতুর্থ...................
# বাংলাদেশ - ঢাকা + ইসলামাবাদ = [(0.6986108422279358, 'পাকিস্তানবাংলাদেশ'), (0.6949124336242676, 'পাকিস্তানযুক্তরাষ্ট্র'), (0.6869184374809265, 'ইসলামাবাদের')]
# ................প্রথম......................
# ...

# %% [markdown]
# ### saving the cbow output

# %%
# Save to Excel format
#excel_file_path = 'analogy_results.xlsx'
# Assuming the DataFrame is the first element of the tuple

data_frame = semantic_cbow_fasttext_model100_min5_w5[0]
data_frame.to_excel('semantic_cbow_fasttext_model100_min5_w5_cbow1.xlsx', index=False, encoding='utf-8')

data_frame = semantic_cbow_fasttext_model300_min5_w5[1]
data_frame.to_excel('semantic_cbow_fasttext_model300_min5_w5_cbow2.xlsx', index=False, encoding='utf-8')

data_frame = semantic_cbow_fasttext_model100_min10_w5[2]
data_frame.to_excel('semantic_cbow_fasttext_model100_min10_w5_cbow3.xlsx', index=False, encoding='utf-8')

data_frame = semantic_cbow_fasttext_model300_min10_w5[3]
data_frame.to_excel('semantic_cbow_fasttext_model300_min10_w5_cbow4.xlsx', index=False, encoding='utf-8')
# Out:
# C:\Users\Inquisitive\anaconda3\envs\data_pre\lib\site-packages\pandas\util\_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)

# %%
data_frame = semantic_cbow_fasttext_model300_min5_w5[1]
data_frame.to_excel('semantic_cbow_fasttext_model300_min5_w5_cbow2.xlsx', index=False, encoding='utf-8')

# %%
data_frame = semantic_cbow_fasttext_model100_min10_w5[2]
data_frame.to_excel('semantic_cbow_fasttext_model100_min10_w5_cbow3.xlsx', index=False, encoding='utf-8')

# %%
data_frame = semantic_cbow_fasttext_model300_min10_w5[3]
data_frame.to_excel('semantic_cbow_fasttext_model300_min10_w5_cbow4.xlsx', index=False, encoding='utf-8')

# %% [markdown]
# ## semantic similarity of words

# %%
# Print the DataFrame
print(semantic_analogy_skip_model_fasttext300_m5_w5)
# Out:
# (                          Input1  \
# 0   ﻿বাংলাদেশ - ঢাকা + ইসলামাবাদ
# 1         বাংলাদেশ - ঢাকা + দোহা
# 2        বাংলাদেশ - ঢাকা + মস্কো
# 3       বাংলাদেশ - ঢাকা + দিল্লি
# 4       বাংলাদেশ - ঢাকা + জেদ্দা
# ..                           ...
# 72             বোন - খালা + চাচা
# 73              চাচা - ভাই + বোন
# 74              খালা - বোন + ভাই
# 75          স্বামী - রাজা + রানি
# 76          রানি - স্ত্রী + রাজা
#
#                                               Output1
# 0   [(0.6415332555770874, দিল্লিইসলামাবাদ), (0.639...
# 1   [(0.7201772332191467, কাতার), (0.7150568366050...
# 2   [(0.7035809755325317, রাশিয়াবেলারুশ), (0.70051...
# 3   [(0.7235133051872253, ভারতের), (0.715625762939...
# 4   [(0.7049050331115723, জেদ্দাস্থ), (0.698773503...
# ..                                                ...
# 72  [(0.8331434726715088, চাচাত), (0.8314678668975...
# 73  [(0.8320208191871643, দাদি), (0.82496118545532...
# 74  [(0.8542352914810181, মামা), (0.81309831142425...
# ...

# %%
skip_model_fasttext100_m10_w5.get_analogies("স্টার্ক" , "অস্ট্রেলিয়া",  "আফ্রিকা", k=3)
# Out:
# [(0.8478803634643555, 'কাগিসো'),
#  (0.8340231776237488, 'রাবাদা'),
#  (0.8336752653121948, 'মরনে')]

# %%
skip_model_fasttext100_m10_w5.get_analogies("স্টার্ক" , "অস্ট্রেলিয়া",  "ভারত", k=3)
# Out:
# [(0.765458881855011, 'জসপ্রিত'),
#  (0.7653314471244812, 'যশপ্রিত'),
#  (0.7647331953048706, 'জসপ্রীত')]

# %%
skip_model_fasttext100_m10_w5.get_analogies("বুমরা" , "ভারত",  "অস্ট্রেলিয়া", k=3)
# Out:
# [(0.8379302620887756, 'হ্যাজলউড'),
#  (0.8366059064865112, 'হ্যাজেলউড'),
#  (0.8351675868034363, 'স্টার্ক')]

# %%
cbow_fasttext_model100min10_w5.get_analogies("বুমরা" , "ভারত",  "আফ্রিকা", k=3)
# Out:
# [(0.6345950961112976, 'কাগিসো'),
#  (0.6339948177337646, 'বুমরাহই'),
#  (0.6289236545562744, 'বোলা')]

# %%
skip_model_fasttext100_m10_w5.get_analogies("বুমরা" , "ভারত",  "আফ্রিকা", k=3)
# Out:
# [(0.8139937520027161, 'ভারনন'),
#  (0.8051783442497253, 'ফিল্যান্ডার'),
#  (0.8004451990127563, 'রাবাদা')]

# %%
skip_model_fasttext300_m10_w5.get_analogies("রাশিয়া" , "মস্কো",  "কিয়েভ", k=3)
# Out:
# [(0.7285619378089905, 'ইউক্রেন'),
#  (0.7234381437301636, 'রাশিয়ার'),
#  (0.7209289073944092, 'ইউক্রেনও')]

# %%
skip_model_fasttext300_m10_w5.get_analogies("রাশিয়া" , "মস্কো",  "তেলআবিব", k=3)
# Out:
# [(0.7692397832870483, 'তেলআবিবে'),
#  (0.7685306072235107, 'তেলআবিবের'),
#  (0.6539195775985718, 'আবিব')]

# %%
skip_model_fasttext300_m10_w5.get_analogies("জার্মানি" , "হিটলার",  "ট্রাম্প", k=3)
# Out:
# [(0.6983787417411804, 'যুক্তরাষ্ট্রমেক্সিকো'),
#  (0.6929781436920166, 'যুক্তরাষ্ট্রজাপান'),
#  (0.6776415109634399, 'যুক্তরাষ্ট্রর')]

# %%
skip_model_fasttext300_m10_w5.get_analogies("জার্মানি" , "হিটলার",  "ট্রাম্প", k=3)
# Out:
# [(0.6983787417411804, 'যুক্তরাষ্ট্রমেক্সিকো'),
#  (0.6929781436920166, 'যুক্তরাষ্ট্রজাপান'),
#  (0.6776415109634399, 'যুক্তরাষ্ট্রর')]

# %%
skip_model_fasttext100_m10_w5.get_analogies("জার্মানি" , "হিটলার",  "মোদি", k=3)
# Out:
# [(0.7327424883842468, 'নয়াদিল্লি'),
#  (0.7174486517906189, 'ভারতজাপান'),
#  (0.7114382386207581, 'ভারতজাপানের')]

# %%
skip_model_fasttext100_m10_w5.get_analogies("জার্মানি" , "হিটলার",  "কিম", k=3)
# Out:
# [(0.7895448207855225, 'কোরিয়া'),
#  (0.7793826460838318, 'কোরিয়ার'),
#  (0.7712321877479553, 'পিয়ংইয়ংয়ে')]

# %%
skip_model_fasttext300_m10_w5.get_analogies("জার্মানি" , "হিটলার",  "শি", k=3)
# Out:
# [(0.6516454219818115, 'চীন'),
#  (0.6379371285438538, 'কোরিয়াযুক্তরাষ্ট্র'),
#  (0.6330815553665161, 'বেইজিং')]

# %%
skip_model_fasttext100_m10_w5.get_analogies("জার্মানি" , "হিটলার",  "ইন্ধিরা", k=3)
# Out:
# [(0.6929947733879089, 'নয়াদিল্লি'),
#  (0.6845511794090271, 'ভারতরাশিয়া'),
#  (0.6811800003051758, 'ভুটান')]

# %%
skip_model_fasttext100_m10_w5.get_analogies("ভারত","মোদি","বঙ্গবন্ধু", k=3)
# Out:
# [(0.592223584651947, 'পাকিস্তানদক্ষিণ'),
#  (0.5893340110778809, 'বঙ্গবন্ধুবঙ্গমাতা'),
#  (0.587208092212677, 'হয়বঙ্গবন্ধু')]

# %%
skip_model_fasttext100_m10_w5.get_analogies('দাদা',"ছেলে" ,"মেয়ে", k=3)
# Out:
# [(0.8052980303764343, 'দাদি'),
#  (0.782932698726654, 'দাদাবাবা'),
#  (0.7733057141304016, 'মা')]

# %%
("জার্মানি" , "হিটলার",  "মোদি", k=3)

# %%
ইউক্রেন - কিয়েভ + দিল্লি

# %%
pwd
# Out:
# 'C:\\Users\\Inquisitive\\Desktop\\models\\fasttext'

# %%
import pandas as pd

# %%
# Load your own trained FastText model
# Replace 'path_to_your_model' with the path to your trained model file
# For example: 'fasttext_model.bin' or 'fasttext_model.vec'
#model_path = 'path_to_your_model'
#model = FastText.load_fasttext_format(model_path)

##skip_model_fasttext100_m5_w5.get_analogies("ছাত্রলীগ","আওয়ামীলীগ", "বিএনপি", k=3)
# Syntactic and Semantic Analogy Task
def analogy(file_path,file_path2):
    results1 = []
    results2=[]
    results3={}
    
    with open(file_path2, 'r', encoding='utf-8') as file:
        for line in file:
            words_truth = line.strip().split()
            #print(words_truth)
            if len(words_truth) == 3:
                #print(words_truth)
                pos1, pos2, pos3 = words_truth
                #print("ok",words_truth)
                results2.append( words_truth)
        #print(results2)        
    
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            words = line.strip().split()
            if len(words) == 3:
                positive, negative, target = words
                
                #result1 = skip_model_fasttext100_m5_w5.get_analogies(positive, negative, target, k=3)  
                #result1=words_truth
                results1.append((f" '{positive}' '{negative}'  '{target}' "))
      
        #print(f"{positive} - {negative} + {target} = {result1}") 
                

           

    df1 = pd.DataFrame(results3, columns=['Input1', 'Output1'])

    return df1

# File path for analogy tasks and most similar word queries
file_path = 'test_bangal_semantic_analogy_final.txt'
file_path2='analogy-semantic-game-country-player-ground-truth.txt'
         

# Perform analogy tasks and most similar word queries from the file
semantic = analogy(file_path,file_path2)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 for p,g in results2 , results1:
#       2     results3.append(results2,results1)
#       4     print(results3)
#
# NameError: name 'results2' is not defined

# %%
with open('analogy-semantic-game-country-player-ground-truth', 'r', encoding='utf-8') as file:
    for lines in file:
        words_truth = line.strip().split()
        if len(words_truth) == 3:
            pos1, pos2, pos3 = words_truth
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 with open('analogy-semantic-game-country-player-ground-truth', 'r', encoding='utf-8') as file:
#       2     for lines in file:
#       3         words_truth = line.strip().split()
#
# File ~\anaconda3\envs\data_pre\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'analogy-semantic-game-country-player-ground-truth'

# %%
with open('analogy-semantic-game-country-player-ground-truth.txt', 'r', encoding='utf-8') as file:
    for line in file:  # Use "line" instead of "lines"
        words_truth = line.strip().split()
        if len(words_truth) == 3:
            pos1, pos2, pos3 = words_truth
            # Do something with pos1, pos2, and pos3 here if needed

# %%
cd ../
# Out:
# C:\Users\Inquisitive\Desktop\models

# %%
cd fasttext
# Out:
# C:\Users\Inquisitive\Desktop\models\fasttext

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6437-7958
#
#  Directory of C:\Users\Inquisitive\Desktop\models\fasttext
#
# 22/09/2023  15:10    <DIR>          .
# 22/09/2023  15:10    <DIR>          ..
# 22/07/2023  18:55    <DIR>          .idea
# 15/09/2023  15:08    <DIR>          .ipynb_checkpoints
# 12/09/2023  12:46             5,013 actual_truth_semantic_analogy_question.txt
# 20/09/2023  03:19             2,176 analogy-semantic-country_capital.txt
# 16/09/2023  14:50             1,517 analogy-semantic-family-power-sex.txt
# 19/09/2023  19:51             1,772 analogy-semantic-game-country-player.txt
# 22/09/2023  14:52             2,026 analogy-semantic-game-country-player-ground-truth.txt
# 16/09/2023  14:49             1,312 analogy-semantic-power-politics-sex.txt
# 19/09/2023  20:55    <DIR>          facebook_fastttext
# 17/06/2023  04:20            10,152 fasttext_facebook_d100min10.ipynb
# ...

# %%
import pandas as pd

def analogy(file_path, file_path2):
    results = []
    
    with open(file_path, 'r', encoding='utf-8') as file1, open(file_path2, 'r', encoding='utf-8') as file2:
        for line1, line2 in zip(file1, file2):
            words = line1.strip().split()
            words_truth = line2.strip().split()
            
            if len(words) == 3 and len(words_truth) == 3:
                positive, negative, target = words
                expected_output = words_truth
                
                #results.append((positive, negative, target, expected_output))
                results.append((f" ('{positive}' '{negative}' '{target}'): , '{expected_output}' "))
                
                ('এমবাপে', 'ফ্রান্স', 'ব্রাজিল'): ['নেইমার', 'নেইমারও', 'নেইমাদের']
                [" 'এমবাপে' 'ফ্রান্স'  'ব্রাজিল' , truth: '['নেইমার', 'নেইমারও', 'নেইমাদের']' ",
        print(results)    
    df = pd.DataFrame(results, columns=['Input1', 'Input2', 'Input3', 'Output'])
    
    return df

# File path for analogy tasks and most similar word queries
file_path = 'analogy-semantic-game-country-player.txt'
file_path2 = 'analogy-semantic-game-country-player-ground-truth.txt'

# Perform analogy tasks and create a DataFrame
semantic = analogy(file_path, file_path2)

# Print the DataFrame
print(semantic)
# Out:
#   Cell In[69], line 18
#     ('এমবাপে', 'ফ্রান্স', 'ব্রাজিল'): ['নেইমার', 'নেইমারও', 'নেইমাদের']
#     ^
# SyntaxError: only single target (not tuple) can be annotated

# %%
# Initialize an empty dictionary to store key-value pairs
analogy_dict = {}

# File paths for the key and value files
file_path1 = 'analogy-semantic-game-country-player.txt'
file_path2 = 'analogy-semantic-game-country-player-ground-truth.txt'

# Read the key and value files and populate the dictionary
with open(file_path1, 'r', encoding='utf-8') as file1, open(file_path2, 'r', encoding='utf-8') as file2:
    keys = file1.readlines()
    values = file2.readlines()
    
    # Remove newline characters from the end of each line
    keys = [key.strip() for key in keys]
    values = [value.strip() for value in values]
    
    # Ensure the number of keys and values match
    if len(keys) == len(values):
        analogy_dict = dict(zip(keys, values))
    else:
        print("Error: The number of keys and values does not match.")

# Print the dictionary
for key, value in analogy_dict.items():
    print(f" '{key}' : {value}")
# Out:
#  'এমবাপে ফ্রান্স ব্রাজিল' : নেইমার নেইমারও নেইমাদের
#  'এমবাপে ফ্রান্স পর্তুগাল' : রোনালদো ক্রিশ্চিয়ানো রোনালদের
#  'রোনালদো পর্তুগাল আর্জেন্টিনা' : মেসি মেসির মেসিদের
#  'নেইমার ব্রাজিল ফ্রান্স' : এমবাপে এমবাপেরা এমবাপ্পে
#  'নেইমার ব্রাজিল পর্তুগাল' : রোনালদো ক্রিশ্চিয়ানো রোনালদের
#  'নেইমার ব্রাজিল আর্জেন্টিনা' : মেসি মেসির মেসিদের
#  'মেসি আর্জেন্টিনা পর্তুগাল' : রোনালদো ক্রিশ্চিয়ানো রোনালদের
#  'মেসি আর্জেন্টিনা ব্রাজিল' : নেইমার নেইমারও নেইমাদের
#  'ব্রাজিল নেইমার মেসি' : আর্জেন্টিনা আর্জেন্টিনার আর্জেন্টিনাও
#  'আর্জেন্টিনা মেসি রোনালদো' : পর্তুগাল পর্তুগালও পর্তুগালের
#  'আর্জেন্টিনা মেসি নেইমার' : ব্রাজিল ব্রাজিলের ব্রাজিলিয়ান
#  'উইলিয়ামসন নিউজিল্যান্ড ভারত' : ভিরাট মহেন্দ্র রোহিত
#  'উইলিয়ামসন নিউজিল্যান্ড অস্ট্রেলিয়া' : ওয়ার্নারফিঞ্চ ফিঞ্চ ওয়ার্নার
#  'নিউজিল্যান্ড উইলিয়ামসন স্মিথ' : অস্ট্রেলিয়া অস্ট্রেলিয় অস্ট্রেলিয়ারও
#  'নিউজিল্যান্ড উইলিয়ামসন স্টার্ক' : অস্ট্রেলিয়া অস্ট্রেলিয় অস্ট্রেলিয়ারও
#  'ভারত ভিরাট উইলিয়ামসন' : নিউজিল্যান্ড কিউইরা কিউইদের
# ...

# %%
# Initialize an empty dictionary to store key-value pairs
analogy_dict = {}

# File paths for the key and value files
file_path1 = 'analogy-semantic-game-country-player.txt'
file_path2 = 'analogy-semantic-game-country-player-ground-truth.txt'


# Read the key and value files and populate the dictionary
with open(file_path1, 'r', encoding='utf-8') as file1, open(file_path2, 'r', encoding='utf-8') as file2:
    keys = file1.readlines()
    values = file2.readlines()

    # Remove newline characters from the end of each line and split into lists of words
    keys = [tuple(line.strip().split()) for line in keys]
    values = [line.strip().split() for line in values]

    # Ensure the number of keys and values match
    if len(keys) == len(values):
        analogy_dict = dict(zip(keys, values))
    else:
        print("Error: The number of keys and values does not match.")

# Print the dictionary
for key, value in analogy_dict.items():
    print(f"{key}: {value},")
# Out:
# ('এমবাপে', 'ফ্রান্স', 'ব্রাজিল'): ['নেইমার', 'নেইমারও', 'নেইমাদের'],
# ('এমবাপে', 'ফ্রান্স', 'পর্তুগাল'): ['রোনালদো', 'ক্রিশ্চিয়ানো', 'রোনালদের'],
# ('রোনালদো', 'পর্তুগাল', 'আর্জেন্টিনা'): ['মেসি', 'মেসির', 'মেসিদের'],
# ('নেইমার', 'ব্রাজিল', 'ফ্রান্স'): ['এমবাপে', 'এমবাপেরা', 'এমবাপ্পে'],
# ('নেইমার', 'ব্রাজিল', 'পর্তুগাল'): ['রোনালদো', 'ক্রিশ্চিয়ানো', 'রোনালদের'],
# ('নেইমার', 'ব্রাজিল', 'আর্জেন্টিনা'): ['মেসি', 'মেসির', 'মেসিদের'],
# ('মেসি', 'আর্জেন্টিনা', 'পর্তুগাল'): ['রোনালদো', 'ক্রিশ্চিয়ানো', 'রোনালদের'],
# ('মেসি', 'আর্জেন্টিনা', 'ব্রাজিল'): ['নেইমার', 'নেইমারও', 'নেইমাদের'],
# ('ব্রাজিল', 'নেইমার', 'মেসি'): ['আর্জেন্টিনা', 'আর্জেন্টিনার', 'আর্জেন্টিনাও'],
# ('আর্জেন্টিনা', 'মেসি', 'রোনালদো'): ['পর্তুগাল', 'পর্তুগালও', 'পর্তুগালের'],
# ('আর্জেন্টিনা', 'মেসি', 'নেইমার'): ['ব্রাজিল', 'ব্রাজিলের', 'ব্রাজিলিয়ান'],
# ('উইলিয়ামসন', 'নিউজিল্যান্ড', 'ভারত'): ['ভিরাট', 'মহেন্দ্র', 'রোহিত'],
# ('উইলিয়ামসন', 'নিউজিল্যান্ড', 'অস্ট্রেলিয়া'): ['ওয়ার্নারফিঞ্চ', 'ফিঞ্চ', 'ওয়ার্নার'],
# ...

# %%
ground_truth = {}
# Assuming your data is stored in a file called 'analogy-semantic-game-country-player-ground-truth.txt'
with open('analogy-semantic-game-country-player-ground-truth.txt', 'r', encoding='utf-8') as file:
    for line in file:
        words = line.strip().split()  # Split each line into words

        if len(words) >= 3:
            analogy = tuple(words[:3])  # Create a tuple of the first three words as the key

            # Check if the analogy key exists in both dictionaries
            if analogy in predicted_results and analogy in ground_truth:
                # Update the predicted_results dictionary with the corresponding value from ground_truth
                print(ground_truth[analogy])
                print("ok")
                predicted_results[analogy] = ground_truth[analogy]

# Now, 'predicted_results' should have the updated values
#print(predicted_results)
